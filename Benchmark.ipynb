# %%
import os
from FeatureSelection import FeatureSelection
import pandas as pd


bench=FeatureSelection("C",5501)

for csv in os.listdir("C:/Users/Kostas/Desktop/testspace2/csvs"):
	data = pd.read_csv("C:/Users/Kostas/Desktop/testspace2/csvs/"+csv, encoding = 'iso-8859-1')
	bench.split_data(data)

bench.uniform('single')
print(bench.p_val_feat['p_val'])
# Out:
# 0         1.898028e-67
# 1        2.226100e-106
# 2         0.000000e+00
# 3         0.000000e+00
# 4         0.000000e+00
# 5        4.296340e-172
# 6         0.000000e+00
# 7        3.184846e-187
# 8        1.691820e-252
# 9        1.256634e-247
# 10        0.000000e+00
# 11        0.000000e+00
# 12       1.046179e-278
# 13       1.209999e-114
# 14       2.811031e-266
# 15       8.057061e-304
# 16        9.831964e-14
# 17        1.299767e-18
# 18       3.475416e-154
# 19        4.169812e-91
# 20        0.000000e+00
# 21        0.000000e+00
# 22        0.000000e+00
# 23       5.155455e-246
# 24       4.753430e-147
# 25        1.556079e-27
# 26       3.677770e-188
# 27       7.945356e-120
# 28       1.787462e-298
# 29        3.768858e-40
#              ...
# 10309    5.533535e-322
# 10310    1.016448e-265
# 10311     2.674203e-59
# 10312    2.881155e-180
# 10313    4.190011e-132
# 10314     0.000000e+00
# 10315     0.000000e+00
# 10316    3.670441e-265
# 10317    3.670441e-265
# 10318    3.568167e-230
# 10319    9.161963e-271
# 10320     0.000000e+00
# 10321    6.164198e-295
# 10322    1.682943e-237
# 10323    8.322327e-151
# 10324    4.572441e-138
# 10325    7.763533e-267
# 10326     0.000000e+00
# 10327    8.505664e-175
# 10328    3.201767e-146
# 10329    3.175339e-255
# 10330     0.000000e+00
# 10331     1.963156e-28
# 10332    3.716147e-176
# 10333     0.000000e+00
# 10334    3.486808e-113
# 10335     0.000000e+00
# 10336     0.000000e+00
# 10337     0.000000e+00
# 10338     0.000000e+00
# Name: p_val, Length: 10339, dtype: float64

# %%
print(bench.p_val_feat['p_val'])
# Out:
# 0        0.936528
# 1        0.936528
# 2        0.936528
# 3        0.936528
# 4        0.936528
# 5        0.843820
# 6        0.936528
# 7        0.843820
# 8        0.936528
# 9        0.936528
# 10       0.936528
# 11       0.936528
# 12       0.936528
# 13       0.936528
# 14       0.936528
# 15       0.936528
# 16       0.843820
# 17       0.843820
# 18       0.936528
# 19       0.843820
# 20       0.936528
# 21       0.843820
# 22       0.936528
# 23       0.936528
# 24       0.936528
# 25       0.843820
# 26       0.843820
# 27       0.843820
# 28       0.936528
# 29       0.936528
#            ...
# 10309    0.936528
# 10310    0.936528
# 10311    0.843820
# 10312    0.936528
# 10313    0.936528
# 10314    0.936528
# 10315    0.936528
# 10316    0.936528
# 10317    0.936528
# 10318    0.936528
# 10319    0.936528
# 10320    0.936528
# 10321    0.936528
# 10322    0.936528
# 10323    0.843820
# 10324    0.843820
# 10325    0.936528
# 10326    0.936528
# 10327    0.843820
# 10328    0.843820
# 10329    0.936528
# 10330    0.936528
# 10331    0.843820
# 10332    0.936528
# 10333    0.936528
# 10334    0.843820
# 10335    0.936528
# 10336    0.936528
# 10337    0.936528
# 10338    0.936528
# Name: p_val, Length: 10339, dtype: float64
